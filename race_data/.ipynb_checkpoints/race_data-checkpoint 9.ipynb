# %%
import pandas as pd
import json
import flask
from flask import Flask, jsonify

# %%
csv = "race_data.csv"

# %%
df = pd.read_csv(csv)
df = df.sort_values(by=['State','Date'])

# %%
df.columns
# Out:
# Index(['Date', 'State', 'Cases_Total', 'Cases_White', 'Cases_Black',
#        'Cases_Latinx', 'Cases_Asian', 'Cases_AIAN', 'Cases_NHPI',
#        'Cases_Multiracial', 'Cases_Other', 'Cases_Unknown',
#        'Cases_Ethnicity_Hispanic', 'Cases_Ethnicity_NonHispanic',
#        'Cases_Ethnicity_Unknown', 'Deaths_Total', 'Deaths_White',
#        'Deaths_Black', 'Deaths_Latinx', 'Deaths_Asian', 'Deaths_AIAN',
#        'Deaths_NHPI', 'Deaths_Multiracial', 'Deaths_Other', 'Deaths_Unknown',
#        'Deaths_Ethnicity_Hispanic', 'Deaths_Ethnicity_NonHispanic',
#        'Deaths_Ethnicity_Unknown'],
#       dtype='object')

# %%
df = df[['Date', 'State', 'Cases_Total', 'Cases_White', 'Cases_Black',
       'Cases_Latinx', 'Cases_Asian', 'Cases_AIAN', 'Cases_NHPI',
       'Cases_Multiracial', 'Cases_Other', 'Cases_Unknown',
       'Cases_Ethnicity_Hispanic', 'Cases_Ethnicity_NonHispanic',
       'Cases_Ethnicity_Unknown', 'Deaths_Total', 'Deaths_White',
       'Deaths_Black', 'Deaths_Latinx', 'Deaths_Asian', 'Deaths_AIAN',
       'Deaths_NHPI', 'Deaths_Multiracial', 'Deaths_Other', 'Deaths_Unknown',
       'Deaths_Ethnicity_Hispanic', 'Deaths_Ethnicity_NonHispanic',
       'Deaths_Ethnicity_Unknown']]

# %%
# replace none and Nan
df
# Out:
#             Date State  Cases_Total  Cases_White  Cases_Black  Cases_Latinx  \
# 93    2020-04-12    AK          NaN          NaN          NaN           NaN
# 91    2020-04-15    AK        293.0        133.0          4.0           NaN
# 24    2020-04-19    AK        319.0        167.0          7.0           NaN
# 26    2020-04-22    AK        335.0        184.0          7.0           NaN
# 28    2020-04-26    AK        341.0        190.0          7.0           NaN
# ...          ...   ...          ...          ...          ...           ...
# 5248  2021-02-21    WY      53795.0      27553.0        417.0        4085.0
# 5237  2021-02-24    WY      53988.0      27671.0        417.0        4095.0
# 5297  2021-02-28    WY      54394.0      27870.0        423.0        4111.0
# 5288  2021-03-03    WY      54616.0      28022.0        424.0        4119.0
# 5309  2021-03-07    WY      54764.0      28117.0        425.0        4134.0
#
#       Cases_Asian  Cases_AIAN  Cases_NHPI  Cases_Multiracial  ...  \
# 93            NaN         NaN         NaN                NaN  ...
# 91           25.0        13.0         3.0                6.0  ...
# 24           33.0        14.0         4.0               10.0  ...
# 26           37.0        18.0         6.0               10.0  ...
# 28           41.0        18.0         6.0                0.0  ...
# ...           ...         ...         ...                ...  ...
# 5248        274.0      2202.0       132.0                NaN  ...
# 5237        277.0      2220.0       132.0                NaN  ...
# 5297        279.0      2227.0       133.0                NaN  ...
# 5288        281.0      2234.0       134.0                NaN  ...
# 5309        281.0      2250.0       134.0                NaN  ...
#
#       Deaths_Latinx  Deaths_Asian  Deaths_AIAN  Deaths_NHPI  \
# 93              NaN           NaN          NaN          NaN
# 91              NaN           2.0          2.0          1.0
# 24              NaN           2.0          2.0          1.0
# 26              NaN           2.0          2.0          1.0
# 28              NaN           2.0          2.0          1.0
# ...             ...           ...          ...          ...
# 5248           57.0           6.0         50.0          1.0
# 5237           57.0           6.0         51.0          1.0
# 5297           57.0           6.0         51.0          1.0
# 5288           58.0           6.0         51.0          1.0
# 5309           58.0           6.0         51.0          1.0
#
#       Deaths_Multiracial  Deaths_Other  Deaths_Unknown  \
# 93                   NaN           NaN             NaN
# 91                   0.0           0.0             2.0
# 24                   0.0           0.0             2.0
# 26                   0.0           0.0             2.0
# 28                   0.0           0.0             0.0
# ...                  ...           ...             ...
# 5248                 NaN           8.0            11.0
# 5237                 NaN           8.0            11.0
# 5297                 NaN           8.0            11.0
# 5288                 NaN           8.0            11.0
# 5309                 NaN           8.0            11.0
#
#       Deaths_Ethnicity_Hispanic  Deaths_Ethnicity_NonHispanic  \
# 93                          NaN                           NaN
# 91                          0.0                           5.0
# 24                          0.0                           5.0
# 26                          0.0                           6.0
# 28                          0.0                           9.0
# ...                         ...                           ...
# 5248                       57.0                         594.0
# 5237                       57.0                         603.0
# 5297                       57.0                         603.0
# 5288                       58.0                         613.0
# 5309                       58.0                         613.0
#
#       Deaths_Ethnicity_Unknown
# 93                         NaN
# 91                         4.0
# 24                         4.0
# 26                         3.0
# 28                         0.0
# ...                        ...
# 5248                      11.0
# 5237                      11.0
# 5297                      11.0
# 5288                      11.0
# 5309                      11.0
#
# [5320 rows x 28 columns]

# %%
df['White Cases %']= df['Cases_White']/df['Cases_Total']
df.dtypes
# Out:
# Date                             object
# State                            object
# Cases_Total                     float64
# Cases_White                     float64
# Cases_Black                     float64
# Cases_Latinx                    float64
# Cases_Asian                     float64
# Cases_AIAN                      float64
# Cases_NHPI                      float64
# Cases_Multiracial               float64
# Cases_Other                     float64
# Cases_Unknown                   float64
# Cases_Ethnicity_Hispanic        float64
# Cases_Ethnicity_NonHispanic     float64
# Cases_Ethnicity_Unknown         float64
# Deaths_Total                    float64
# Deaths_White                    float64
# Deaths_Black                    float64
# Deaths_Latinx                   float64
# Deaths_Asian                    float64
# Deaths_AIAN                     float64
# Deaths_NHPI                     float64
# Deaths_Multiracial              float64
# Deaths_Other                    float64
# Deaths_Unknown                  float64
# Deaths_Ethnicity_Hispanic       float64
# Deaths_Ethnicity_NonHispanic    float64
# Deaths_Ethnicity_Unknown        float64
# White Cases %                   float64
# dtype: object

# %%
df.to_csv('race_data.csv', index=False)
